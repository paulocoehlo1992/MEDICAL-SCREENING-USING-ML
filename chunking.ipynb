# %%
import pandas as pd
import numpy as np

# %%
PATH = "./data/qa.csv"
df = pd.read_csv(PATH, nrows = 10)
df
# Out:
#    MAGNUM_QUESTION_RK PROPOSAL_DT  POS_APPLICATION_NO  SUM_ASSURED  \
# 0                 229  08/01/2016       1100039396174       143016
# 1                 229  08/01/2016       1100039396274       110140
# 2                 229  21/04/2015       1100000033033       150000
# 3                 229  28/05/2015       1100000113033       300000
# 4                 229  28/05/2015       1100000113245      2500000
# 5                 229  25/03/2016       1394480647645      7500000
# 6                 229  08/01/2016       2100039397916      1000000
# 7                 229  18/03/2016       1100039679318      7500000
# 8                 229  21/04/2015       1100000033775       150000
# 9                 229  28/05/2015       2100000113254       300000
#
#    PREMIUM_AMT    CHANNEL SUB_CHANNEL  ANSWER     QUESTION_ID  \
# 0        24124  HDFC BANK   HDFC BANK     NaN  OccStuStandard
# 1        15000     Agency      Agency     NaN  OccStuStandard
# ...

# %%
df.columns
# Out:
# Index(['MAGNUM_QUESTION_RK', 'PROPOSAL_DT', 'POS_APPLICATION_NO',
#        'SUM_ASSURED', 'PREMIUM_AMT', 'CHANNEL', 'SUB_CHANNEL', 'ANSWER',
#        'QUESTION_ID', 'QUESTION_TEXT'],
#       dtype='object')

# %%
# for yearMon in [(year*100 + mon) for mon in range(1,13) for year in range(2015,2017)]:
#     df.head(0).to_csv('./chunks/' + str(yearMon) + '.csv', index = False)

# chunker = pd.read_csv(PATH, chunksize=10000)

# for piece in chunker:
#     piece['PROPOSAL_DT_index'] = pd.to_datetime(piece['PROPOSAL_DT'], format='%d/%m/%Y')
#     piece.set_index(['PROPOSAL_DT_index'], inplace= True)
#     for n,g in piece.groupby(pd.Grouper(freq='M')):
#         name = './chunks/' + n.strftime('%Y%m') + '.csv'
#         g.to_csv(name, mode = "a", header = False, index = False)

# %%
df_demog = pd.read_csv("./data/demographics.csv", nrows = 100)
df_demog.head().T
# Out:
#                                              0                     1  \
# PROPOSAL_DT                         10/08/2015            10/08/2015
# POS_APPLICATION_NO               1100007901970         1100007910571
# SUM_ASSURED                            2500000                250000
# PREMIUM_AMT                             250000                 25000
# CHANNEL                                 Direct             HDFC BANK
# SUB_CHANNEL                            Loyalty             HDFC BANK
# DOB                      12/5/1972 12:00:00 AM  6/2/1987 12:00:00 AM
# GENDER                                    Male                  Male
# WEIGHT                                      75                    68
# HEIGHT                      5ft 10ins = 178cms     5ft 6ins = 168cms
# MARITAL_STATUS                         Married               Married
# EDUCATION_QUALIFICATION                  B Com                   GRD
# INCOME                                  966864                500000
#
# ...

# %%
df_demog.columns
# Out:
# Index(['PROPOSAL_DT', 'POS_APPLICATION_NO', 'SUM_ASSURED', 'PREMIUM_AMT',
#        'CHANNEL', 'SUB_CHANNEL', 'DOB', 'GENDER', 'WEIGHT', 'HEIGHT',
#        'MARITAL_STATUS', 'EDUCATION_QUALIFICATION', 'INCOME'],
#       dtype='object')

# %%
#!sudo rstudio-server start
